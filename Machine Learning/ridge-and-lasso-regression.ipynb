# %% [markdown]
# # Ridge and Lasso Regressors

# %% [markdown]
# ### Why it came about?
#
# When your model ends up overfitting to its data, you add `penalty scores` to the ****cost function**.
# The method of adding the penalty gives us 2 different regressors:
# - Ridge Regressor
# - Lasso Regressor

# %% [markdown]
# ## Ridge Regressor (L2 Regularization)

# %% [markdown]
# Loss in Ridge Regressor is given as:
#
# $$Loss = MSE + λ*\sum_{i=1}^{n} w_i$$
